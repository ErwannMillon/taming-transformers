# %%
import pandas as pd
imgs = pd.read_csv("./list_attr_celeba.csv")

# %%
att = imgs.loc[imgs["Attractive"] == 1][:100]["image_id"]
not_att = imgs.loc[imgs["Attractive"] == -1 & imgs][:100]["image_id"]

# %%
print(not_att)
import matplotlib.pyplot as plt
import PIL
print(type(not_att.loc[2]) )
path = "./img_align_celeba/"
plt.imshow(PIL.Image.open(path + not_att.loc[2]).convert("RGB"))
# Out:
# 1      000002.jpg
# 2      000003.jpg
# 7      000008.jpg
# 12     000013.jpg
# 13     000014.jpg
#           ...
# 209    000210.jpg
# 211    000212.jpg
# 212    000213.jpg
# 214    000215.jpg
# 217    000218.jpg
# Name: image_id, Length: 100, dtype: object
# <class 'str'>
